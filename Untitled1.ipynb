# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# Upload your data as a csv file and load it as a data frame 
dataset = pd.read_csv("data.csv" , encoding= 'unicode_escape').dropna()
dataset.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
dataset['command_price'] = dataset.Quantity * dataset.UnitPrice
dataset['command_price'] = dataset['command_price'].astype(int)
dataset
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  command_price
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom             15
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom             20
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom             22
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom             20
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom             20
# ...                 ...        ...         ...             ...            ...
# 541904  12/9/2011 12:50       0.85     12680.0          France             10
# 541905  12/9/2011 12:50       2.10     12680.0          France             12
# 541906  12/9/2011 12:50       4.15     12680.0          France             16
# 541907  12/9/2011 12:50       4.15     12680.0          France             16
# 541908  12/9/2011 12:50       4.95     12680.0          France             14
#
# [406829 rows x 9 columns]

# %%
selected_atributes = [ 'InvoiceNo' , 'StockCode' , 'Quantity' , 'UnitPrice' , 'CustomerID' , 'Country' , 'command_price']

# %%
dataset = dataset[ dataset['CustomerID'].notna() ] 
dataset = dataset[ dataset['StockCode'].notna() ] 
dataset = dataset[ dataset['Quantity'] > 0 ] 
dataset = dataset[ dataset['UnitPrice'] > 0 ] 

dataset['CustomerID'] = dataset['CustomerID'].astype(int)
dataset['InvoiceNo'] = dataset.InvoiceNo.astype(str)
dataset['InvoiceNo'] = dataset.InvoiceNo.str.extract(r'(\d+)', expand=True).astype(int)
dataset['StockCode'] = dataset.StockCode.astype(str)
dataset['StockCode'] = dataset.StockCode.str.extract(r'(\d+)', expand=True)
dataset= dataset[dataset['StockCode'].isnull() == False]

dataset['StockCode'] = dataset.StockCode.astype(int)

# %%
X = dataset[selected_atributes]
X
# Out:
#         InvoiceNo  StockCode  Quantity  UnitPrice  CustomerID         Country  \
# 0          536365      85123         6       2.55       17850  United Kingdom
# 1          536365      71053         6       3.39       17850  United Kingdom
# 2          536365      84406         8       2.75       17850  United Kingdom
# 3          536365      84029         6       3.39       17850  United Kingdom
# 4          536365      84029         6       3.39       17850  United Kingdom
# ...           ...        ...       ...        ...         ...             ...
# 541904     581587      22613        12       0.85       12680          France
# 541905     581587      22899         6       2.10       12680          France
# 541906     581587      23254         4       4.15       12680          France
# 541907     581587      23255         4       4.15       12680          France
# 541908     581587      22138         3       4.95       12680          France
#
#         command_price
# 0                  15
# 1                  20
# 2                  22
# 3                  20
# 4                  20
# ...               ...
# 541904             10
# 541905             12
# 541906             16
# 541907             16
# 541908             14
#
# [396470 rows x 7 columns]

# %%
# Visualize the correlation your data and identify variables for further analysis
g = sns.PairGrid(X)
g.map(sns.scatterplot);
